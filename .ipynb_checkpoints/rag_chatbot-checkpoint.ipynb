# %%
import os
import glob
from dotenv import load_dotenv
import gradio as gr

# %%
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.schema import Document
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
import plotly.graph_objects as go
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.embeddings import HuggingFaceEmbeddings

# %%
MODEL = "gpt-4o-mini"
db_name = "vector_db"

# %%
load_dotenv(override=True)
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')

# %%
folders = glob.glob("knowledge-base/*")

def add_metadata(doc, doc_type):
    doc.metadata["doc_type"] = doc_type
    return doc

# With thanks to CG and Jon R, students on the course, for this fix needed for some users 
text_loader_kwargs = {'encoding': 'utf-8'}
# If that doesn't work, some Windows users might need to uncomment the next line instead
# text_loader_kwargs={'autodetect_encoding': True}

documents = []
for folder in folders:
    doc_type = os.path.basename(folder)
    loader = DirectoryLoader(folder, glob="**/*.md", loader_cls=TextLoader, loader_kwargs=text_loader_kwargs)
    folder_docs = loader.load()
    documents.extend([add_metadata(doc, doc_type) for doc in folder_docs])

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.split_documents(documents)

print(f"Total number of chunks: {len(chunks)}")
print(f"Document types found: {set(doc.metadata['doc_type'] for doc in documents)}")
# Out:
# Total number of chunks: 0
# Document types found: set()

# %%
embeddings = OpenAIEmbeddings()

# If you would rather use the free Vector Embeddings from HuggingFace sentence-transformers
# Then replace embeddings = OpenAIEmbeddings()
# with:
# from langchain.embeddings import HuggingFaceEmbeddings
# embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Delete if already exists

if os.path.exists(db_name):
    Chroma(persist_directory=db_name, embedding_function=embeddings).delete_collection()

# Create vectorstore

vectorstore = Chroma.from_documents(documents=chunks, embedding=embeddings, persist_directory=db_name)
print(f"Vectorstore created with {vectorstore._collection.count()} documents")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 16
#      12     Chroma(persist_directory=db_name, embedding_function=embeddings).delete_collection()
#      14 # Create vectorstore
# ---> 16 vectorstore = Chroma.from_documents(documents=chunks, embedding=embeddings, persist_directory=db_name)
#      17 print(f"Vectorstore created with {vectorstore._collection.count()} documents")
#
# File C:\ProgramData\anaconda3\envs\llms\Lib\site-packages\langchain_chroma\vectorstores.py:1388, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, host, port, headers, chroma_cloud_api_key, tenant, database, client_settings, client, collection_metadata, collection_configuration, ssl, **kwargs)
#    1386 if ids is None:
#    1387     ids = [doc.id if doc.id else str(uuid.uuid4()) for doc in documents]
# -> 1388 return cls.from_texts(
#    1389     texts=texts,
#    1390     embedding=embedding,
#    1391     metadatas=metadatas,
#    1392     ids=ids,
#    1393     collection_name=collection_name,
#    1394     persist_directory=persist_directory,
#    1395     host=host,
#    1396     port=port,
#    1397     ssl=ssl,
#    1398     headers=headers,
#    1399     chroma_cloud_api_key=chroma_cloud_api_key,
#    1400     tenant=tenant,
#    1401     database=database,
#    1402     client_settings=client_settings,
#    1403     client=client,
#    1404     collection_metadata=collection_metadata,
#    1405     collection_configuration=collection_configuration,
#    1406     **kwargs,
#    1407 )
#
# File C:\ProgramData\anaconda3\envs\llms\Lib\site-packages\langchain_chroma\vectorstores.py:1321, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, host, port, headers, chroma_cloud_api_key, tenant, database, client_settings, client, collection_metadata, collection_configuration, ssl, **kwargs)
#    1313     from chromadb.utils.batch_utils import create_batches
#    1315     for batch in create_batches(
#    1316         api=chroma_collection._client,
#    1317         ids=ids,
#    1318         metadatas=metadatas,  # type: ignore[arg-type]
#    1319         documents=texts,
#    1320     ):
# -> 1321         chroma_collection.add_texts(
#    1322             texts=batch[3] if batch[3] else [],
#    1323             metadatas=batch[2] if batch[2] else None,  # type: ignore[arg-type]
#    1324             ids=batch[0],
#    1325         )
#    1326 else:
#    1327     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
# File C:\ProgramData\anaconda3\envs\llms\Lib\site-packages\langchain_chroma\vectorstores.py:673, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     667         self._collection.upsert(
#     668             embeddings=embeddings_without_metadatas,  # type: ignore[arg-type]
#     669             documents=texts_without_metadatas,
#     670             ids=ids_without_metadatas,
#     671         )
#     672 else:
# --> 673     self._collection.upsert(
#     674         embeddings=embeddings,  # type: ignore[arg-type]
#     675         documents=texts,
#     676         ids=ids,
#     677     )
#     678 return ids
#
# File C:\ProgramData\anaconda3\envs\llms\Lib\site-packages\chromadb\api\models\Collection.py:365, in Collection.upsert(self, ids, embeddings, metadatas, documents, images, uris)
#     340 def upsert(
#     341     self,
#     342     ids: OneOrMany[ID],
#    (...)    352     uris: Optional[OneOrMany[URI]] = None,
#     353 ) -> None:
#     354     """Update the embeddings, metadatas or documents for provided ids, or create them if they don't exist.
#     355
#     356     Args:
#    (...)    363         None
#     364     """
# --> 365     upsert_request = self._validate_and_prepare_upsert_request(
#     366         ids=ids,
#     367         embeddings=embeddings,
#     368         metadatas=metadatas,
#     369         documents=documents,
#     370         images=images,
#     371         uris=uris,
#     372     )
#     374     self._client._upsert(
#     375         collection_id=self.id,
#     376         ids=upsert_request["ids"],
#    (...)    382         database=self.database,
#     383     )
#
# File C:\ProgramData\anaconda3\envs\llms\Lib\site-packages\chromadb\api\models\CollectionCommon.py:95, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      92 @functools.wraps(func)
#      93 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#      94     try:
# ---> 95         return func(self, *args, **kwargs)
#      96     except Exception as e:
#      97         msg = f"{str(e)} in {name}."
#
# File C:\ProgramData\anaconda3\envs\llms\Lib\site-packages\chromadb\api\models\CollectionCommon.py:405, in CollectionCommon._validate_and_prepare_upsert_request(self, ids, embeddings, metadatas, documents, images, uris)
#     389 @validation_context("upsert")
#     390 def _validate_and_prepare_upsert_request(
#     391     self,
#    (...)    403 ) -> UpsertRequest:
#     404     # Unpack
# --> 405     upsert_records = normalize_insert_record_set(
#     406         ids=ids,
#     407         embeddings=embeddings,
#     408         metadatas=metadatas,
#     409         documents=documents,
#     410         images=images,
#     411         uris=uris,
#     412     )
#     414     # Validate
#     415     validate_insert_record_set(record_set=upsert_records)
#
# File C:\ProgramData\anaconda3\envs\llms\Lib\site-packages\chromadb\api\types.py:271, in normalize_insert_record_set(ids, embeddings, metadatas, documents, images, uris)
#     255 def normalize_insert_record_set(
#     256     ids: OneOrMany[ID],
#     257     embeddings: Optional[
#    (...)    266     uris: Optional[OneOrMany[URI]] = None,
#     267 ) -> InsertRecordSet:
#     268     """
#     269     Unpacks and normalizes the fields of an InsertRecordSet.
#     270     """
# --> 271     base_record_set = normalize_base_record_set(
#     272         embeddings=embeddings, documents=documents, images=images, uris=uris
#     273     )
#     275     return InsertRecordSet(
#     276         ids=cast(IDs, maybe_cast_one_to_many(ids)),
#     277         metadatas=maybe_cast_one_to_many(metadatas),
#    (...)    281         uris=base_record_set["uris"],
#     282     )
#
# File C:\ProgramData\anaconda3\envs\llms\Lib\site-packages\chromadb\api\types.py:248, in normalize_base_record_set(embeddings, documents, images, uris)
#     237 def normalize_base_record_set(
#     238     embeddings: Optional[Union[OneOrMany[Embedding], OneOrMany[PyEmbedding]]] = None,
#     239     documents: Optional[OneOrMany[Document]] = None,
#     240     images: Optional[OneOrMany[Image]] = None,
#     241     uris: Optional[OneOrMany[URI]] = None,
#     242 ) -> BaseRecordSet:
#     243     """
#     244     Unpacks and normalizes the fields of a BaseRecordSet.
#     245     """
#     247     return BaseRecordSet(
# --> 248         embeddings=normalize_embeddings(embeddings),
#     249         documents=maybe_cast_one_to_many(documents),
#     250         images=maybe_cast_one_to_many(images),
#     251         uris=maybe_cast_one_to_many(uris),
#     252     )
#
# File C:\ProgramData\anaconda3\envs\llms\Lib\site-packages\chromadb\api\types.py:145, in normalize_embeddings(target)
#     142     return None
#     144 if len(target) == 0:
# --> 145     raise ValueError(
#     146         f"Expected Embeddings to be non-empty list or numpy array, got {target}"
#     147     )
#     149 if isinstance(target, list):
#     150     # One PyEmbedding
#     151     if isinstance(target[0], (int, float)) and not isinstance(target[0], bool):
#
# ValueError: Expected Embeddings to be non-empty list or numpy array, got [] in upsert.

# %%
collection = vectorstore._collection
count = collection.count()

sample_embedding = collection.get(limit=1, include=["embeddings"])["embeddings"][0]
dimensions = len(sample_embedding)
print(f"There are {count:,} vectors with {dimensions:,} dimensions in the vector store")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 collection = vectorstore._collection
#       2 count = collection.count()
#       4 sample_embedding = collection.get(limit=1, include=["embeddings"])["embeddings"][0]
#
# NameError: name 'vectorstore' is not defined

# %%
result = collection.get(include=['embeddings', 'documents', 'metadatas'])
vectors = np.array(result['embeddings'])
documents = result['documents']
metadatas = result['metadatas']
doc_types = [metadata['doc_type'] for metadata in metadatas]
colors = [['blue', 'green', 'red', 'orange'][['products', 'employees', 'contracts', 'company'].index(t)] for t in doc_types]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 result = collection.get(include=['embeddings', 'documents', 'metadatas'])
#       2 vectors = np.array(result['embeddings'])
#       3 documents = result['documents']
#
# NameError: name 'collection' is not defined

# %%
tsne = TSNE(n_components=2, random_state=42)
reduced_vectors = tsne.fit_transform(vectors)

# Create the 2D scatter plot
fig = go.Figure(data=[go.Scatter(
    x=reduced_vectors[:, 0],
    y=reduced_vectors[:, 1],
    mode='markers',
    marker=dict(size=5, color=colors, opacity=0.8),
    text=[f"Type: {t}<br>Text: {d[:100]}..." for t, d in zip(doc_types, documents)],
    hoverinfo='text'
)])

fig.update_layout(
    title='2D Chroma Vector Store Visualization',
    scene=dict(xaxis_title='x',yaxis_title='y'),
    width=800,
    height=600,
    margin=dict(r=20, b=10, l=10, t=40)
)

fig.show()

# %%
tsne = TSNE(n_components=3, random_state=42)
reduced_vectors = tsne.fit_transform(vectors)

# Create the 3D scatter plot
fig = go.Figure(data=[go.Scatter3d(
    x=reduced_vectors[:, 0],
    y=reduced_vectors[:, 1],
    z=reduced_vectors[:, 2],
    mode='markers',
    marker=dict(size=5, color=colors, opacity=0.8),
    text=[f"Type: {t}<br>Text: {d[:100]}..." for t, d in zip(doc_types, documents)],
    hoverinfo='text'
)])

fig.update_layout(
    title='3D Chroma Vector Store Visualization',
    scene=dict(xaxis_title='x', yaxis_title='y', zaxis_title='z'),
    width=900,
    height=700,
    margin=dict(r=20, b=10, l=10, t=40)
)

fig.show()

# %%
# create a new Chat with OpenAI
llm = ChatOpenAI(temperature=0.7, model_name=MODEL)

# Alternative - if you'd like to use Ollama locally, uncomment this line instead
# llm = ChatOpenAI(temperature=0.7, model_name='llama3.2', base_url='http://localhost:11434/v1', api_key='ollama')

# set up the conversation memory for the chat
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)

# the retriever is an abstraction over the VectorStore that will be used during RAG
retriever = vectorstore.as_retriever()

# putting it together: set up the conversation chain with the GPT 3.5 LLM, the vector store and memory
conversation_chain = ConversationalRetrievalChain.from_llm(llm=llm, retriever=retriever, memory=memory)

# %%
query = "Please explain what Insurellm is in a couple of sentences"
result = conversation_chain.invoke({"question": query})
print(result["answer"])

# %%
# set up a new conversation memory for the chat
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)

# putting it together: set up the conversation chain with the GPT 4o-mini LLM, the vector store and memory
conversation_chain = ConversationalRetrievalChain.from_llm(llm=llm, retriever=retriever, memory=memory)

# %%
def chat(question, history):
    result = conversation_chain.invoke({"question": question})
    return result["answer"]

# %%
view = gr.ChatInterface(chat, type="messages").launch(inbrowser=True)

# %%
from langchain_core.callbacks import StdOutCallbackHandler

llm = ChatOpenAI(temperature=0.7, model_name=MODEL)

memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)

retriever = vectorstore.as_retriever()

conversation_chain = ConversationalRetrievalChain.from_llm(llm=llm, retriever=retriever, memory=memory, callbacks=[StdOutCallbackHandler()])

query = "Who received the prestigious IIOTY award in 2023?"
result = conversation_chain.invoke({"question": query})
answer = result["answer"]
print("\nAnswer:", answer)

# %%
llm = ChatOpenAI(temperature=0.7, model_name=MODEL)

# set up the conversation memory for the chat
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)

# the retriever is an abstraction over the VectorStore that will be used during RAG; k is how many chunks to use
retriever = vectorstore.as_retriever(search_kwargs={"k": 25})

# putting it together: set up the conversation chain with the GPT 3.5 LLM, the vector store and memory
conversation_chain = ConversationalRetrievalChain.from_llm(llm=llm, retriever=retriever, memory=memory)

# %%
def chat(question, history):
    result = conversation_chain.invoke({"question": question})
    return result["answer"]

# %%
view = gr.ChatInterface(chat, type="messages").launch(inbrowser=True)
